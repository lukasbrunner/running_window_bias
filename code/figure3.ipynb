# %% [markdown]
# # Figure 3: spatial bias inhomogeneities
#
# (c) 2023 under a MIT License (https://mit-license.org)
#
# Author: Lukas Brunner (l.brunner@univie.ac.at)

# %%
import os
import xarray as xr
import matplotlib as mpl

from core.matrixplot import (
    matrixplot, 
    # load_data_matrix,
)
from core.io_functions import PLOT_PATH, DATA_PATH

mpl.rc('font', **{'size': 14})

# %% [markdown]
# ## Figure 3a: Spatial bias inhomogeneity

# %%
# ds = load_data_matrix()
# ds.to_netcdf(os.path.join(DATA_PATH, 'figure3a.nc'))

# %%
ds = xr.open_dataset(os.path.join(DATA_PATH, 'figure3a.nc'))
fig, ax = matrixplot(ds, vmax=55)
ax.set_title('(a) Spatial bias inhomogeneity')
# fig.savefig(os.path.join(PLOT_PATH, 'figure3a.png'), dpi=300)
fig.savefig(os.path.join(PLOT_PATH, 'figure3a.pdf'), dpi=300)

# %% [markdown]
# ## Figure 3a: Spatial bias inhomogeneity corrected

# %%
# ds = load_data_matrix(deseasonalized=True)
# ds.to_netcdf(os.path.join(DATA_PATH, 'figure3b.nc'))

# %%
ds = xr.open_dataset(os.path.join(DATA_PATH, 'figure3b.nc'))
fig, ax = matrixplot(ds, vmax=55)
ax.set_title('(b) Corrected: Spatial bias inhomogeneity')
# fig.savefig(os.path.join(PLOT_PATH, 'figure3b.png'), dpi=300)
fig.savefig(os.path.join(PLOT_PATH, 'figure3b.pdf'), dpi=300)
